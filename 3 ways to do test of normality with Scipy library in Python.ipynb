# %% [markdown]
# # 3 ways to do test of normality with Scipy library in Python

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# https://docs.scipy.org/doc/numpy-1.15.0/reference/routines.random.html
a = np.random.randn(1000) # conforms to the normal distribution
b = np.random.rand(1000) # random values in 0 to 1

# %%
fig = plt.figure(figsize=(10, 5))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

ax1.hist(a, bins=100)
ax2.hist(b, bins=100)
fig.tight_layout()
plt.show()

# %%
import scipy.stats as stats
fig2 = plt.figure(figsize=(10, 5))
ax3 = fig2.add_subplot(1, 2, 1)
ax4 = fig2.add_subplot(1, 2, 2)
stats.probplot(a, dist='norm', plot=ax3)
stats.probplot(b, dist='norm', plot=ax4)
fig2.tight_layout()
plt.show()

# %%
from scipy import stats
c = stats.shapiro(a)
d = stats.shapiro(b)

# %%
print('W statistic is {0} and p-value is {1}'.format(c[0], c[1]))
# Out:
# W statistic is 0.9990878701210022 and p-value is 0.9145322442054749

# %%
print('W statistic is {0} and p-value is {1}'.format(d[0], d[1]))
# Out:
# W statistic is 0.9530125856399536 and p-value is 2.3810294670665395e-17

# %%
stats.describe(a)
# Out:
# DescribeResult(nobs=1000, minmax=(-3.0896070820367454, 2.932222322086782), mean=0.032817199005045004, variance=0.9915275763728507, skewness=-0.05963014120009394, kurtosis=-0.09261602436820882)

# %%
stats.describe(b)
# Out:
# DescribeResult(nobs=1000, minmax=(8.466331538625749e-05, 0.9993388890872057), mean=0.4999988893524324, variance=0.08535758984330624, skewness=-0.009869988030472118, kurtosis=-1.2034649761255165)

# %%
print('Skewness is {0} and Kurtosis is {1}'.format(stats.skew(a), stats.kurtosis(a, fisher=False)))
# Out:
# Skewness is -0.05963014120009394 and Kurtosis is 2.907383975631791

# %%
print('Skewness is {0} and Kurtosis is {1}'.format(stats.skew(b), stats.kurtosis(b, fisher=False)))
# Out:
# Skewness is -0.009869988030472118 and Kurtosis is 1.7965350238744835
